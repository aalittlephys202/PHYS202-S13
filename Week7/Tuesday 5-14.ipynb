# %%
g = 9.8 #m/s^2
l = 0.5 #m
th0 = 20.*pi/180 #20 degrees, but must use radians

t = arange(0.,10.+0.01,0.01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)
    
plot(t,theta_app(t))
show()

# %%
def deriv(theta_current,t): #return derivatives of the array theta
    g = 9.8
    l = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array([dtheta, domega])

# %%
from scipy.integrate import odeint

# %%
t = arange(0.,10.+0.01,0.01)

omega0 = 0. #starting from rest, omega = 0
theta_init = array([th0, omega0]) #initial  values, th0 from before = 20 

theta = odeint(deriv, theta_init,t) #pass the function deriv to the solver

# %%
#theta.shape

# %%
plot(t,theta_app(t),'b-', t,theta[:,0],'r--')
show()

# %%
th0 = 50.*pi/180 # 50 degrees
theta_init = array([th0, omega0]) #initial values
theta = odeint(deriv,theta_init,t)

plot(t,theta_app(t),'b-',t,theta[:,0],'r--')
show()

# %% [markdown]
# Exercise 1
# ==========

# %%
th0 = 0 # 0 degrees
theta_init = array([th0, omega0]) #initial values
theta = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta[:,0],'r--')

th1 = 45.*pi/180 # pi/4 degrees
theta_init = array([th1, omega0]) #initial values
theta1 = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta1[:,0],'b--')

th2 = 90.*pi/180 # pi/2 degrees
theta_init = array([th2, omega0]) #initial values
theta2 = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta2[:,0],'y--')

th3 = 135.*pi/180 # 3pi/4 degrees
theta_init = array([th3, omega0]) #initial values
theta3 = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta3[:,0],'g--')

th4 = pi # pi degrees
theta_init = array([th4, omega0]) #initial values
theta4 = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta4[:,0],'r--')
# Out:
# [<matplotlib.lines.Line2D at 0x8a64d68>,
#  <matplotlib.lines.Line2D at 0x8a6d198>]

# %% [markdown]
# Exercise 2
# ==========

# %%
th0 = 171.*pi/180 # 0 degrees
theta_init = array([th0, omega0]) #initial values
theta5 = odeint(deriv,theta_init,t)
plot(t,theta_app(t),'b-',t,theta5[:,1],'r--')
# Out:
# [<matplotlib.lines.Line2D at 0xb9380b8>,
#  <matplotlib.lines.Line2D at 0xb9384e0>]

# %%
plot(theta_app(t),theta5[:,1])

# %% [markdown]
# Exercise 3
# ==========

# %%
E = g*h + 0.5*
