# %% [markdown]
# Question 1
# ==========

# %% [markdown]
# Academic Honesty Pledge
#
# Cal Poly PHYS 202 - Spring 2013
#
# I have read and understand the rules regarding academic honesty and I agree to abide by them.
# I pledge on my honor that I have not given or received any unauthorized assistance on assignments or ex-
# aminations in this course.
#
# Signed: Alex Little
# Dated: 5/7/2013

# %% [markdown]
# Question 2
# ==========

# %% [markdown]
# (a)
# ===

# %%
theta = arange(-pi,pi,0.1)
y = (cos(2*theta)**2)*(cos(theta/2))**2
plot(theta,y, color="red")
xlabel("theta(rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0x86f1390>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
theta = arange(-pi,pi,0.1)
y = (cos(2*theta)**2)*(cos(theta/2))**2
plot(theta,y, color="blue", linestyle="--")
xlabel("theta(rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0xbf1fe80>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#cant get star to work
theta = arange(-pi,pi,0.1)
y = (cos(2*theta)**2)*(cos(theta/2))**2
plot(theta,y, color="blue", linestyle="*")
xlabel("theta(rad)")
ylabel("intensity")
xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
# Out:
# ([<matplotlib.axis.XTick at 0xc4f0128>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# (b)
# ===

# %%
t = arange(-5,5,0.1)
f = exp(-t)
g = (t+1)/(t-1)
plot(t,f,color="red",linestyle=":", label="exp(-t)")
plot(t,g,color="blue", label="(t+1)/(t-1)")
xlabel("time(seconds)")
ylabel("f(t),g(t)")
legend(loc="lower left")

# %% [markdown]
# Question 3
# ==========

# %%
from Electrostatics import *

# %%
import scipy.integrate as integrate

# %%
a = 1.0
b = 2.0
q = 1e-6
Xq = 3
Yq = 3
result = integrate.quad(pointField(a,b,q,Xq,Yq), a, b)
print result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c16524f96efd> in <module>()
#       4 Xq = 3
#       5 Yq = 3
# ----> 6 result = integrate.quad(pointField(a,b,q,Xq,Yq), a, b)
#       7 print result
#
# C:\Users\Alex\Documents\GitHub\PHYS202-S13\Midterm\Electrostatics.pyc in pointField(x, y, q, Xq, Yq)
#      17     """E is for the Ex value and W is the Ey value"""
#      18     k = 8.9875518*10**9
# ---> 19     E = (k*q(x-Xq))/((x-Xq)**2 + (y-Yq)**2)**0.5
#      20     W = (k*q(y-Yq))/((x-Xq)**2 + (y-Yq)**2)**0.5
#      21     print E
#
# TypeError: 'float' object is not callable

# %%
def pointField(x,y,q,Xq,Yq):
    """E is for the Ex value and W is the Ey value"""
    k = 8.9875518*10**9
    E= (k*q(x-Xq))/((x-Xq)**2 + (y-Yq)**2)**0.5
    W = (k*q(y-Yq))/((x-Xq)**2 + (y-Yq)**2)**0.5
    print E
    print W
result = integrate.quad(pointField(a,b,q,Xq,Yq),a,b)
print result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e32774315b75> in <module>()
#       6     print E
#       7     print W
# ----> 8 result = integrate.quad(pointField(a,b,q,Xq,Yq),a,b)
#       9 print result
#
# <ipython-input-11-e32774315b75> in pointField(x, y, q, Xq, Yq)
#       2     """E is for the Ex value and W is the Ey value"""
#       3     k = 8.9875518*10**9
# ----> 4     E= (k*q(x-Xq))/((x-Xq)**2 + (y-Yq)**2)**0.5
#       5     W = (k*q(y-Yq))/((x-Xq)**2 + (y-Yq)**2)**0.5
#       6     print E
#
# TypeError: 'float' object is not callable

# %% [markdown]
# (c)
# ===

# %%
r=2e-6
l = lambda x: r*(x/b)**2

# %% [markdown]
# Question 4
# ==========

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'
for letter in prefixes:
    print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Oack
# Pack
# Qack

# %% [markdown]
# (a)
# ===

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'
for letter in prefixes:
    if letter == "O" or letter == "Q":
        print letter + "u" + suffix
    else:
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %% [markdown]
# (b)
# ===

# %%
s1 = "what"
s2 = "thaw"
def is_anagram(s1,s2):
    if len(s1)==len(s2):
        for letter in s1,s2:
            if letter==letter:
                return True
            else:
                False
    else:
        False

        
is_anagram(s1,s2)
# Out:
# True
