# %% [markdown]
# 3D Plotting And Functions

# %%
import math
import numpy as np

# %%
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))

x.ndim
y.shape
# Out:
# (200L, 200L)

# %%
print x,y
# Out:
# [[-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]
#  [-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]
#  [-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]
#  ...,
#  [-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]
#  [-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]
#  [-6.   -5.94 -5.88 ...,  5.82  5.88  5.94]] [[-6.   -6.   -6.   ..., -6.   -6.   -6.  ]
#  [-5.94 -5.94 -5.94 ..., -5.94 -5.94 -5.94]
#  [-5.88 -5.88 -5.88 ..., -5.88 -5.88 -5.88]
#  ...,
#  [ 5.82  5.82  5.82 ...,  5.82  5.82  5.82]
#  [ 5.88  5.88  5.88 ...,  5.88  5.88  5.88]
#  [ 5.94  5.94  5.94 ...,  5.94  5.94  5.94]]

# %% [markdown]
# Create 2 dimensional array to define functions and two dimensional figures

# %% [markdown]
# Electric Dipole Potential
# =========================

# %% [markdown]
# \begin{equation}
# V(x,y)=\frac{kq}{\sqrt{(x^2)+(y-d)^2}}-\frac{kq}{\sqrt{(x^2)+(y+d)^2}}
# \end{equation}

# %%
k=1 ; q=1 ;d=1

# %%
V = (k*q/(x**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y+d)**2)**(1/2.)))
G = exp((-(x**2)-(y**2)))
#put a period after 1/2  because it was a float(something about float)
print V
# Out:
# [[-0.01957165 -0.02074131 -0.02198058 ..., -0.02220337 -0.02095177
#   -0.01977017]
#  [-0.01991818 -0.02115669 -0.02247407 ..., -0.02271145 -0.02138005
#   -0.02012805]
#  [-0.02023504 -0.02154403 -0.02294204 ..., -0.02319456 -0.02178065
#   -0.02045649]
#  ...,
#  [ 0.02028665  0.02160802  0.02302026 ...,  0.02327547  0.02184697
#    0.02051012]
#  [ 0.01997559  0.02122626  0.02255749 ...,  0.02279747  0.0214519
#    0.02018746]
#  [ 0.01963378  0.02081528  0.02206793 ...,  0.02229321  0.02102795
#    0.01983425]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x, y, V, rstride=1,cstride=1, linewidth=0, cmap=cm.rainbow)
#normal x and y between -2,2 i changed to -6,6
cb = fig.colorbar(p, shrink=0.5)

# %%
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])
contour(x,y,V,levels,cmap=cm.cubehelix)
show()

# %% [markdown]
# Question 1
# ==========

# %% [markdown]
# \begin{equation}
# G(x,y) = e^{-x^2 - y^2}
# \end{equation}

# %%
dx = 0.23
dy = 0.23
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))


from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x,y,G, rstride=1,cstride=1, linewidth=0, cmap=cm.rainbow)

cb = fig.colorbar(p, shrink=0.5)

cset = ax.contour(x, y, G, zdir='x', offset=-6, cmap=cm.BuGn)

# %% [markdown]
# Question 2
# ==========

# %%
from mpl_toolkits.mplot3d import Axes3D
k = 8.9875518*10**9 #N m^2/C^2
q1 = -1*10**-9 #C
q2 = -1*10**-9 #C
q3 = 1*10**-9 #C
q4 = 1*10**-9 #C
d = 1
V1 = (k*q1/((x+2)**2 + (y - d)**2)**(1/2.) - (k*q1/(x**2 + (y + 2 + d)**2)**(1/2.)))
V2 = (k*q2/((x-2)**2 + (y - d)**2)**(1/2.) - (k*q2/(x**2 + (y - 2 + d)**2)**(1/2.)))

dx = 0.08
dy = 0.08
x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))
x.ndim
y.shape
levels = array([4., 2., 1., .5, .25, 0., -.25, -.5, -1., -2., -4.])
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,V1, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm) # cm. then hit tab
p = ax.plot_surface(x,y,V2, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)

# %% [markdown]
# Question 3
# ==========

# %% [markdown]
# a)

# %%
def pointPotential(x,y,q,posx,posy):
    """does something"""
    k = 8.9875518*10**9
    q1 = -1*10**-9
    d=1
    Vab = k*q*(x**2+y**2)**-.5
    return Vab

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vab = pointPotential(x,y,1e-9,0.,0.)
print Vab
# Out:
# [[ 3.17757941  3.22559495  3.27428946 ...,  3.30710904  3.25798498
#    3.20951244]
#  [ 3.22559495  3.27585506  3.32689793 ...,  3.36134185  3.30979899
#    3.25901295]
#  [ 3.27428946  3.32689793  3.38040363 ...,  3.41655455  3.36247083
#    3.30926048]
#  ...,
#  [ 3.30710904  3.36134185  3.41655455 ...,  3.45389067  3.3980434
#    3.3431539 ]
#  [ 3.25798498  3.30979899  3.36247083 ...,  3.3980434   3.34482043
#    3.29243068]
#  [ 3.20951244  3.25901295  3.30926048 ...,  3.3431539   3.29243068
#    3.24242797]]

# %% [markdown]
# b)

# %%
q1 = -1*10**-9
d=1
def dipolePotential(x,y,q,d):
    """does something"""
    k = 8.9875518*10**9
    q1 = -1*10**-9
    d=1
    Vxy = (k*q1/(x**2 + (y - d)**2)**(1/2.) - (k*q1/(x**2 + (y + d)**2)**(1/2.)))
    return Vxy

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = dipolePotential(x,y,q1,d)
print Vxy
# Out:
# [[ 1.52665698  1.6022041   1.68209807 ...,  1.73789923  1.65496846
#    1.57655087]
#  [ 1.53938717  1.61758022  1.70045818 ...,  1.7584568   1.67229388
#    1.59100937]
#  [ 1.54998969  1.63076109  1.71656371 ...,  1.77672638  1.6873834
#    1.60329437]
#  ...,
#  [-1.55576088 -1.63820032 -1.72590493 ..., -1.78748094 -1.69606276
#   -1.61015302]
#  [-1.54670621 -1.6266273  -1.71146343 ..., -1.77090977 -1.68261909
#   -1.59945622]
#  [-1.53536885 -1.61268616 -1.69457464 ..., -1.75184346 -1.66675364
#   -1.5864192 ]]

# %% [markdown]
# c)

# %%
def pointPotential(x,y,q,posx,posy):
    """does something"""
    k = 8.9875518*10**9
    q1 = -1*10**-9
    d=1
    Vab = k*q*(x**2+y**2)**-.5
    return Vab

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vab = pointPotential(x,y,1e-9,0.,0.)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection="3d")
p = ax.plot_surface(x, y, Vab, rstride=1,cstride=1, linewidth=0, cmap=cm.rainbow)
#normal x and y between -2,2 i changed to -6,6
cb = fig.colorbar(p, shrink=0.5)

# %%
q = 1*10**-9
d=1
def dipolePotential(x,y,q,d):
    k = 8.9875518*10**9 #setting k, q, and d values
    q = 1*10**-9
    d=1
    Vxy = (k*q/(x**2 + (y - d)**2)**(1/2.) - (k*q/(x**2 + (y + d)**2)**(1/2.))) #insert Vxy function
    return Vxy #return Vxy

x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy = dipolePotential(x,y,q,d)

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(x,y,Vxy, rstride=1, cstride=1, linewidth=0, cmap=cm.coolwarm)
