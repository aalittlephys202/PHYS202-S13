# %%
import numpy.random
numpy.random?

# %%
#print 5 uniformly distributed numbers 0 and 1
print numpy.random.random(5)
#print another 5 - should be different
print numpy.random.random(5)
# Out:
# [ 0.36664501  0.07508521  0.22691154  0.50465248  0.55751681]
# [ 0.85672657  0.27556963  0.61577242  0.52699325  0.92301482]

# %%
#now set the seed to something:
numpy.random.seed(4242)
#print 5 random numbers from the generator with this seed
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#Restore the seed to its orginal 'None'
numpy.random.seed(None)

# print 5 more numbers usinge the new random seed
print "Using seed = None:"
print numpy.random.random(5)
# Out:
# Using seed = None:
# [ 0.85206548  0.930877    0.12829859  0.54401221  0.26170765]

# %%
#reset the seed to 4242 and print again
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before:"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %% [markdown]
# Sampling from a continuous distribution
# =

# %% [markdown]
# Example 1

# %%
x = arange(0., pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x),label='True distribution', lw=3)
plot(x,F(x),label='Cumulative function', lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#numbers of samples
N= 10000

#N random numbers between 0 and 1 
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#sampled  x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %% [markdown]
# Exercise 1
# =

# %% [markdown]
# \begin{equation}
# f(x) = \lambda e^{-\lambda x}
# \end{equation}

# %% [markdown]
# (a)

# %% [markdown]
# \begin{equation}
# F(x) = -e^{-\lambda x}
# \end{equation}
# \begin{equation}
# Finv(x) = -ln(x)
# \end{equation}

# %% [markdown]
# (b)

# %%
x = arange(0.1,5+0.01,0.01)
f = lambda x: exp(-x)
g = lambda x: -exp(-x)
F = lambda x: -log(x)
    
plot(x,f(x),label='True distribution', lw=3)
#plot(x,F(x),label='CDF', lw=3)
plot(x,g(x),label='guess',lw=3)

xlim(0,5)
ylim(-3,3)

legend(loc=0)
show()

# %% [markdown]
# (c)

# %%
#numbers of samples
N= 10000

#N random numbers between 0 and 1 
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: -log(z)
    
#sampled  x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,1)

legend(loc=0)
show()

# %% [markdown]
# Exercise 2
# =

# %% [markdown]
# (a)

# %%
import numpy

# %%
t = numpy.random.random_sample(N)
y = arange(0.,5,0.1)
f = lambda y: exp(-y)
cdf = cumsum(f(y))/sum(f(y))

cdf
# Out:
# array([ 0.09580813,  0.18249891,  0.26093998,  0.33191639,  0.3961385 ,
#         0.45424907,  0.50682969,  0.5544066 ,  0.59745597,  0.63640865,
#         0.67165449,  0.70354625,  0.7324031 ,  0.75851386,  0.78213986,
#         0.80351754,  0.82286087,  0.84036344,  0.85620041,  0.8705303 ,
#         0.88349652,  0.89522885,  0.90584469,  0.9154503 ,  0.92414182,
#         0.93200623,  0.93912224,  0.94556108,  0.95138718,  0.95665885,
#         0.96142885,  0.96574493,  0.96965028,  0.97318399,  0.97638142,
#         0.97927458,  0.98189241,  0.98426113,  0.98640443,  0.98834377,
#         0.99009856,  0.99168635,  0.99312305,  0.99442303,  0.9955993 ,
#         0.99666363,  0.99762668,  0.99849808,  0.99928656,  1.        ])

# %%
#numbers of samples
N= 10000

#N random numbers between 0 and 1 
z = numpy.random.random_sample(N);
    
#sampled  y values
xsamples = y[cdf.searchsorted(z)]
#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,1)

legend(loc=0)
show()

# %% [markdown]
# (c)

# %%
def distribute1D(x,prob,N):
    F = cumsum(prob)/sum(prob)
    z=numpy.random.random_sample(N)
    T = F.searchsorted(z)
    xsamples = x[T]
    return xsamples

r = distribute1D(x,f(x),10000)
hist(r,50, normed=True)
# Out:
# (array([  1.73333333e-01,   2.93333333e-01,   1.33333333e-02,
#          3.20000000e-01,   1.06666667e-01,   1.33333333e-02,
#          0.00000000e+00,   2.66666667e-02,   1.46666667e-01,
#          6.53333333e-01,   3.46666667e-01,   4.53333333e-01,
#          1.37333333e+00,   1.60000000e-01,   1.20000000e-01,
#          4.00000000e-02,   8.00000000e-02,   2.30666667e+00,
#          5.20000000e+00,   1.32000000e+00,   1.74533333e+01,
#          1.29066667e+01,   6.32000000e+00,   2.72133333e+01,
#          1.25733333e+01,   7.18666667e+00,   2.07333333e+01,
#          3.44000000e+00,   4.05333333e+00,   3.69333333e+00,
#          2.53333333e-01,   1.46666667e-01,   5.33333333e-02,
#          2.66666667e-02,   9.73333333e-01,   7.20000000e-01,
#          2.40000000e-01,   8.00000000e-01,   2.00000000e-01,
#          2.66666667e-02,   4.00000000e-02,   0.00000000e+00,
#          1.46666667e-01,   4.66666667e-01,   6.66666667e-02,
#          2.00000000e-01,   2.40000000e-01,   0.00000000e+00,
#          0.00000000e+00,   1.33333333e-02]),
#  array([-0.177 , -0.1695, -0.162 , -0.1545, -0.147 , -0.1395, -0.132 ,
#        -0.1245, -0.117 , -0.1095, -0.102 , -0.0945, -0.087 , -0.0795,
#        -0.072 , -0.0645, -0.057 , -0.0495, -0.042 , -0.0345, -0.027 ,
#        -0.0195, -0.012 , -0.0045,  0.003 ,  0.0105,  0.018 ,  0.0255,
#         0.033 ,  0.0405,  0.048 ,  0.0555,  0.063 ,  0.0705,  0.078 ,
#         0.0855,  0.093 ,  0.1005,  0.108 ,  0.1155,  0.123 ,  0.1305,
#         0.138 ,  0.1455,  0.153 ,  0.1605,  0.168 ,  0.1755,  0.183 ,
#         0.1905,  0.198 ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# Exercise 3
# =

# %%
x = arange(-0.2, 0.2+0.0005, 0.001)
a = 10**-5
d = 15*10**-6
L = 1
lam=632.8*10**-9
f = lambda x: (sinc((a*x)/(lam*L))**2)*(cos((2*pi*d*x)/(lam*L))**2)
plot(x, f(x))
show()

# %%
D = distribute1D(x,f(x),10000)

# %% [markdown]
# (b)

# %%
plot(x,f(x),color='red',lw=3, label='True distribution')
hist(D, 100, normed=True, color='blue', label='Sampled distribution')
legend(loc=0)
show()

# %%
n, bins, patches = hist(D,50,normed=True,label="Sampled data")
plot(x,f(x)*max(n),'r-',label='True distribution',linewidth=4)

# %% [markdown]
# (c)

# %%
#one photon
D1 = distribute1D(x,f(x),1)
n, bins, patches = hist(D1,100,normed=True,label="Sampled Data")
plot(x,f(x)*max(n),'r-',lw=3,label='True distribution')
legend(loc=0)
show()

# %%
#ten photons
D2 = distribute1D(x,f(x),10)
n, bins, patches = hist(D2,100,normed=True,label="Sampled data")
plot(x,f(x)*max(n),'r-',lw=3,label='True distribution')
legend(loc=0)
show()

# %%
#one hundred photons
D3 = distribute1D(x,f(x),100)
n, bins, patches = hist(D3,100,normed=True,label="Sampled data")
plot(x,f(x)*max(n),'r-',lw=3,label='True distribution')
legend(loc=0)
show()

# %%
#one thousand photons
D4 = distribute1D(x,f(x),1000)
n, bins, patches = hist(D4,100,normed=True,label="Sampled data")
plot(x,f(x)*max(n),'r-',lw=3,label='True distribution')
legend(loc=0)
show()

# %%
#ten thousand photons
D5 = distribute1D(x,f(x),10000)
n, bins, patches = hist(D5,100,normed=True,label="Sampled data")
plot(x,f(x)*max(n),'r-',lw=3,label='True distribution')
legend(loc=0)
show()
