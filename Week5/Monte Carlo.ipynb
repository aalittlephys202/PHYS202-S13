# %%
l = w = 4.
r = 1.375
Nin = 15
N = 40
Aboard = l*w
Aexact = pi*r**2
Acirc = (Nin/float(N))*Aboard #since we calc a ratio, make sure they are floats!
print "Aboard=", Aboard
print "Aexact=", Aexact
print "Acirc=", Acirc
print "Error=", (100.*(Acirc-Aexact)/Aexact),"%"
# Out:
# Aboard= 16.0
# Aexact= 5.93957361069
# Acirc= 6.0
# Error= 1.01735230957 %

# %% [markdown]
# Example 1
# =========

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$x^{1/2} + \sin(x)$',fontsize=20)
xlabel(r'$x$',fontsize=20)
xlim(0.,15.)

show()

# %%
xmin = 1.7
xmax = 12.4

#find the maximum value of f within boundary to set ymax
subx = x[logical_and((x > xmin),(x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

#Replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)


#plot the box
plot([xmin,xmin],[ymin,ymax], color='k',linestyle='--') #vertical left
plot([xmax,xmax],[ymin,ymax], color='k',linestyle='--') #vertical right
plot([xmin,xmax],[ymax,ymax], color='k',linestyle='--') #horizontal top

show()

# %%
#random sample?

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#Replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#plot the box
plot([xmin,xmin],[ymin,ymax], color='k',linestyle='--') #vertical left
plot([xmax,xmax],[ymin,ymax], color='k',linestyle='--') #vertical right
plot([xmin,xmax],[ymax,ymax], color='k',linestyle='--') #horizontal top

show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6273

# %%
#Replot my function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#Show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

#plot the box
plot([xmin,xmin],[ymin,ymax], color='k',linestyle='--') #vertical left
plot([xmax,xmax],[ymin,ymax], color='k',linestyle='--') #vertical right
plot([xmin,xmax],[ymax,ymax], color='k',linestyle='--') #horizontal top

show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.9101160639

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exaxt =",Iexact
print "I_hitormiss =",I
print "Error on I=",Ierr,"%"
# Out:
# I_exaxt = 26.5172145362
# I_hitormiss = 26.9101160639
# Error on I= -1.48168476416 %

# %% [markdown]
# Exercise 1:
# ===========

# %%
xmin = 1.7
xmax = 12.4

#find the maximum value of f within boundary to set ymax
subx = x[logical_and((x > xmin),(x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

N = 10000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#Replot my function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#Show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

#plot the box
plot([xmin,xmin],[ymin,ymax], color='k',linestyle='--') #vertical left
plot([xmax,xmax],[ymin,ymax], color='k',linestyle='--') #vertical right
plot([xmin,xmax],[ymax,ymax], color='k',linestyle='--') #horizontal top

show()

I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I

Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exaxt =",Iexact
print "I_hitormiss =",I
print "Error on I=",Ierr,"%"
# Out:
# 26.9101160639
# I_exaxt = 26.5172145362
# I_hitormiss = 26.9101160639
# Error on I= -1.48168476416 %

# %% [markdown]
# Exercise 2
# ==========
